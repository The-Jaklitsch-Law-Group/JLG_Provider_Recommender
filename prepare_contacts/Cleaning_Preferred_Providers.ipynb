# %% [markdown]
# # Cleaning Contact Data - Preferred Providers

# %%
import pandas as pd

# %%
df = pd.read_excel('../data/raw/Referral_App_Preferred_Providers.xlsx')
df = df.drop_duplicates(ignore_index=True)
df
# Out:
#                                              Full Name  Person ID  \
# 0              Absolute Chiropractic Care - Lanham, MD  993709552
# 1           Absolute Chiropractic Care - Oxon Hill, MD  993726318
# 2             Absolute Chiropractic Care - Waldorf, MD  996733740
# 3       Active Life Physical Therapy - Lutherville, MD  996605037
# 4              Active Physical Therapy - Annapolis, MD  996733800
# ..                                                 ...        ...
# 431             University Physical Therapy Associates  996748084
# 432  Waldorf Total Health Chiropractic & Physical T...  996701857
# 433           Washington Circle Orthopaedic Associates  996740755
# 434  Winchester Orthopaedic Associates - Main Locat...  996738975
# 435  Winchester Orthopaedic Associates - Satellite ...  996738976
#
#                                 Contact's Work Address Contact's Work Phone  \
# 0     9470 Annapolis Road, Suite 403, Lanham, MD 20706       (301) 577-1800
# ...

# %%
df[df["Contact's Details: Latitude"].isna()].to_excel('../data/processed/Preferred_Providers_Missing_LatLong.xlsx', index=False)
