# %% [markdown]
# # EDA - List of Projects - Provider Referrals

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# pd.set_option('display.max_rows', None)

# %%
df = pd.read_excel('./data/List of Contacts - Provider Referrals.xlsx',
                    parse_dates = ['Create Date',
                                    'Date of Intake',
                                    'Sign Up Date'],
                    dtype = {'Dr/Facility Referred To Address 1 Zip':str})
df
# Out:
#      Project ID         Create Date Date of Intake Sign Up Date  \
# 0     992307748 2025-07-31 13:09:03     2025-07-31   2025-07-31
# 1     992302238 2025-07-21 10:11:49     2025-07-21   2025-07-21
# 2     992300036 2025-07-15 13:36:33     2025-07-15   2025-07-15
# 3     992299997 2025-07-15 12:59:08     2025-07-14   2025-07-14
# 4     992296111 2025-07-07 16:11:53     2025-07-06   2025-07-06
# ..          ...                 ...            ...          ...
# 351   991916980 2024-06-13 17:32:15     2024-06-10   2024-06-13
# 352   991915746 2024-06-11 16:51:43     2024-06-11   2024-06-11
# 353   992146586 2024-08-14 08:41:31     2024-08-13   2024-08-13
# 354   991752417 2024-01-10 15:47:29     2023-12-19   2023-12-20
# 355   992259841 2025-04-17 15:34:05     2025-04-10   2025-04-17
#
#      Dr/Facility Referred To Person Id  \
# 0                            996356411
# 1                            996356411
# 2                            996356411
# ...

# %%
# ## Select 

# df['Referred Date'] = df[['Date of Intake', 'Sign Up Date']].max(axis = 1)
# df['Referred Date'] = df['Referred Date'].fillna(value = df['Create Date'])
# df['Referred Date'].isna().sum()

# %%
## Assume that the "Sign Up Date" is most accurate, then "Date of Intake", else "Create Date"

df['Referred Date'] = df['Sign Up Date'].fillna(value = df['Date of Intake'])
df['Referred Date'] = df['Referred Date'].fillna(value = df['Create Date'])
df['Referred Date'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Referred Date']
# Out:
# 0     2025-07-31
# 1     2025-07-21
# 2     2025-07-15
# 3     2025-07-14
# 4     2025-07-06
#          ...
# 351   2024-06-13
# 352   2024-06-11
# 353   2024-08-13
# 354   2023-12-20
# 355   2025-04-17
# Name: Referred Date, Length: 356, dtype: datetime64[ns]

# %%
df = df.drop(columns = ['Create Date', 'Date of Intake', 'Sign Up Date'])
df
# Out:
#      Project ID  Dr/Facility Referred To Person Id  \
# 0     992307748                          996356411
# 1     992302238                          996356411
# 2     992300036                          996356411
# 3     992299997                          996356411
# 4     992296111                          996356411
# ..          ...                                ...
# 351   991916980                          996605561
# 352   991915746                          993709552
# 353   992146586                          996702174
# 354   991752417                          996702174
# 355   992259841                          993724575
#
#                      Dr/Facility Referred To Full Name  \
# 0               Dunkirk Chiropractic & Wellness Center
# 1               Dunkirk Chiropractic & Wellness Center
# 2               Dunkirk Chiropractic & Wellness Center
# 3               Dunkirk Chiropractic & Wellness Center
# 4               Dunkirk Chiropractic & Wellness Center
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356 entries, 0 to 355
# Data columns (total 10 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Project ID                                356 non-null    int64
#  1   Dr/Facility Referred To Person Id         356 non-null    int64
#  2   Dr/Facility Referred To Full Name         356 non-null    object
#  3   Dr/Facility Referred To Address 1 Line 1  356 non-null    object
#  4   Dr/Facility Referred To Address 1 City    356 non-null    object
#  5   Dr/Facility Referred To Address 1 State   356 non-null    object
#  6   Dr/Facility Referred To Address 1 Zip     356 non-null    object
#  7   Client's Details: Latitude                0 non-null      float64
#  8   Client's Details: Longitude               0 non-null      float64
#  9   Referred Date                             356 non-null    datetime64[ns]
# ...

# %%
df = df.sort_values(by = 'Referred Date', ascending = True)
df
# Out:
#      Project ID  Dr/Facility Referred To Person Id  \
# 276   991272125                          996605635
# 239   991350821                          996605523
# 85    991350809                          996701857
# 275   991349758                          996605635
# 84    991352802                          996701857
# ..          ...                                ...
# 88    992308178                          996701816
# 198   992309632                          996576449
# 199   992309581                          996576449
# 26    992310813                          996701857
# 216   992314325                          996613409
#
#                      Dr/Facility Referred To Full Name  \
# 276              Bezak Chiropractic And Rehabilitation
# 239      Effective Integrative Healthcare - Lanham, MD
# 85   Waldorf Total Health Chiropractic & Physical T...
# 275              Bezak Chiropractic And Rehabilitation
# 84   Waldorf Total Health Chiropractic & Physical T...
# ...

# %%
df[['Dr/Facility Referred To Address 1 Line 1','Dr/Facility Referred To Full Name']].sort_values(by = 'Dr/Facility Referred To Address 1 Line 1')
# Out:
#     Dr/Facility Referred To Address 1 Line 1  \
# 10              10020 Southern Maryland Blvd
# 11              10020 Southern Maryland Blvd
# 1               10020 Southern Maryland Blvd
# 9               10020 Southern Maryland Blvd
# 2               10020 Southern Maryland Blvd
# ..                                       ...
# 349                       9300 Livingston Rd
# 352                      9470 Annapolis Road
# 353                  9601 Pulaski Park Drive
# 354                  9601 Pulaski Park Drive
# 355                        9632 Deereco Road
#
#                      Dr/Facility Referred To Full Name
# 10              Dunkirk Chiropractic & Wellness Center
# 11              Dunkirk Chiropractic & Wellness Center
# 1               Dunkirk Chiropractic & Wellness Center
# 9               Dunkirk Chiropractic & Wellness Center
# 2               Dunkirk Chiropractic & Wellness Center
# ..                                                 ...
# ...

# %%
df[['Dr/Facility Referred To Address 1 Line 1','Dr/Facility Referred To Full Name']].value_counts().sort_index()
# Out:
# Dr/Facility Referred To Address 1 Line 1  Dr/Facility Referred To Full Name
# 10020 Southern Maryland Blvd              Dunkirk Chiropractic & Wellness Center                          24
# 10845 Town Center Boulevard               Dunkirk Family Practice                                          1
# 1110 Benfield Blvd                        NeuroPro Concussion Clinic                                       1
# 12102 Old Line Center                     Waldorf Total Health Chiropractic & Physical Therapy            60
# 128 Greentree Drive                       NovaCare Rehabilitation                                          1
#                                                                                                           ..
# 836 N Roling Road                         ATI Physical Therapy - Catonsville                               1
# 9300 Livingston Rd                        KAIZO HEALTH CHIROPRACTIC & REHABILITATION - FORT WASHINGTON    13
# ...
